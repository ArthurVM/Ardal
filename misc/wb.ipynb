# %%
# %matplotlib ipympl
# %matplotlib qt

import sys
import time
import io
from Bio import Phylo
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PyQt5
from sklearn.decomposition import NMF, PCA
from scipy.cluster.hierarchy import dendrogram, linkage, to_tree
from scipy.spatial.distance import squareform
from sklearn.preprocessing import StandardScaler
from collections import defaultdict
from ardal import Ardal
# import _ardal


def makePCA(matrix, categories, D3=True, Dplus=False):
    """
    Performs PCA on a matrix and visualizes the results with a legend.

    Args:
        matrix (pd.DataFrame): The input matrix (rows are samples, columns are features).
        categories (dict): A dictionary mapping matrix indices (sample IDs) to categories.
        D3 (bool): Whether to create a 3D plot (default: True).
        Dplus (bool): Whether to use a size map (default: False).

    Raises:
        ValueError: If the matrix is not a Pandas DataFrame or if categories is not a dictionary.
    """

    # Input validation
    if not isinstance(matrix, pd.DataFrame):
        raise ValueError("matrix must be a Pandas DataFrame.")
    if not isinstance(categories, dict):
        raise ValueError("categories must be a dictionary.")

    matrix_indices = matrix.index
    matrix_standardized = StandardScaler().fit_transform(matrix)

    n = min(len(matrix_indices), 20)
    pca = PCA(n_components=n)
    pca_result = pca.fit_transform(matrix_standardized)
    pca_df = pd.DataFrame(data=pca_result[:, :4], columns=['PC1', 'PC2', 'PC3', 'PC4'], index=matrix_indices)
    
    ## fill missing samples in categories dict
    for key in pca_df.T.keys():
        if key not in categories:
            print(key)
            categories[key] = None
            
    # Color setup
    unique_categories = sorted(set(categories.values()))
    cmap = sns.color_palette("Spectral", as_cmap=True)
    colours = [cmap(i) for i in np.linspace(0, 1, len(unique_categories))]
    cdict = dict(zip(unique_categories, colours))

    # Plotting
    if D3:
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(111, projection='3d')

        if Dplus:
            min_val = pca_df["PC4"].min()
            max_val = pca_df["PC4"].max()
            sizemap = 100 + ((pca_df['PC4'] - min_val) * 100) / (max_val - min_val)
            scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], pca_df['PC3'], s=sizemap, alpha=0.8)
        else:
            for category in unique_categories:
                indices = [idx for idx, cat in categories.items() if cat == category]
                subset = pca_df.loc[indices]
                scatter = ax.scatter(subset['PC1'], subset['PC2'], subset['PC3'], alpha=0.8, c=[cdict[category]] * len(subset), label=category)

            ax.legend()

        ax.set_zlabel('PC3')

    else:
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(111)

        if Dplus:
            min_val = pca_df['PC3'].min()
            max_val = pca_df['PC3'].max()
            sizemap = 200 + ((pca_df['PC3'] - min_val) * 50) / (max_val - min_val)
            scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], s=sizemap, alpha=0.7)
        else:
            for category in unique_categories:
                # indices = [idx for idx, cat in categories.items() if cat == category]
                # subset = pca_df.loc[indices]
                scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], alpha=0.8, c=[cdict[category]] * len(pca_df), label=category)

            ax.legend()

    ax.set_xlabel('PC1')
    ax.set_ylabel('PC2')
    ax.grid(True)

    plt.show()

def plot_colored_tree(
    newick_string: str,
    category_map: dict,
    title: str = "Phylogenetic Tree",
    uncategorized_label: str = 'None',
    uncategorized_color: str = 'grey'
):
    """
    Parses a Newick tree string and plots the tree with tip labels colored
    by category. Colors are assigned automatically and a legend is generated.

    Args:
        newick_string (str): The phylogenetic tree in Newick format.
        category_map (dict): A dictionary mapping tip names (str) to category names (str).
                             e.g., {'leaf1': 'Group A', 'leaf2': 'None'}
        title (str, optional): The title for the plot. Defaults to "Phylogenetic Tree".
        uncategorized_label (str, optional): The label for items to be considered
                                             uncategorized. Defaults to 'None'.
        uncategorized_color (str, optional): The color for uncategorized items.
                                             Defaults to 'grey'.
    """
    try:
        # Use io.StringIO to treat the string as a file, which Phylo.read expects.
        tree_file = io.StringIO(newick_string)
        tree = Phylo.read(tree_file, "newick")
    except Exception as e:
        print(f"Error: Failed to parse the Newick string. Details: {e}")
        return

    # 1. Identify unique categories, EXCLUDING the special uncategorized label.
    all_values = set(category_map.values())
    unique_categories = sorted([cat for cat in all_values if cat != uncategorized_label])

    # 2. Automatically generate a color for each "real" category.
    if len(unique_categories) <= 10:
        cmap = plt.get_cmap('tab10')
    elif len(unique_categories) <= 20:
        cmap = plt.get_cmap('tab20')
    else:
        cmap = plt.get_cmap('viridis', len(unique_categories))

    # Create a dictionary mapping each category name to its assigned color.
    category_to_color = {category: cmap(i) for i, category in enumerate(unique_categories)}
    
    # 3. Add the special color for the uncategorized group.
    category_to_color[uncategorized_label] = uncategorized_color

    # 4. Define a function for Phylo.draw to look up the color for each label.
    def get_label_color(label):
        category = category_map.get(str(label), uncategorized_label)
        return category_to_color.get(category, 'black')

    # 5. Create the matplotlib figure and axes.
    fig, ax = plt.subplots(figsize=(10, 25)) # Increased height for better visibility
    fig.suptitle(title, fontsize=10)

    # Draw the tree.
    Phylo.draw(
        tree,
        axes=ax,
        do_show=False,
        label_colors=get_label_color,
        branch_labels=None
    )

    # 6. Create a legend DIRECTLY from the category-to-color mapping. This is the fix.
    handles = [plt.Line2D([0], [0], marker='o', color='w', label=category,
                          markerfacecolor=color, markersize=10)
               for category, color in category_to_color.items() if category != uncategorized_label]

    if handles:
        ax.legend(handles=handles, title="Categories", loc="best")

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()



def getNewick(node, newick, parentdist, leaf_names):
    if node.is_leaf():
        return "%s:%.2f%s" % (leaf_names[node.id], parentdist - node.dist, newick)
    else:
        if len(newick) > 0:
            newick = "):%.2f%s" % (parentdist - node.dist, newick)
        else:
            newick = ");"
        newick = getNewick(node.get_left(), newick, node.dist, leaf_names)
        newick = getNewick(node.get_right(), ",%s" % (newick), node.dist, leaf_names)
        newick = "(%s" % (newick)
        return newick
    
    
def dist2newick(data):

    sample_names = list(data.index)
    # Create a list of tuples for linkage information
    z = linkage(squareform(data, force='tovector'), 'ward')
    tree = to_tree(z, False)
    nwk = getNewick(tree, "", tree.dist, sample_names)

    return nwk


def makecmap(cats):
    colors = plt.cm.rainbow(np.linspace(0, 1, len(cats)))
    coldict = {x[0] : x[1] for x in zip(cats, colors)}
    return coldict


def clamp(x): 
  x = x*255
  return int(max(0, min(x, 255)))


def cluster(dist_matrix, nclusters):
    from sklearn.cluster import KMeans

    dist_array = dist_matrix.values

    # Perform k-means clustering
    kmeans = KMeans(n_clusters=nclusters, random_state=0, n_init='auto')  # Set random_state for reproducibility
    cluster_labels = kmeans.fit_predict(dist_array)

    # Create the cluster membership dictionary
    cluster_membership = {}
    for i, guid in enumerate(dist_matrix.index):
        cluster_membership[guid] = cluster_labels[i]

    return cluster_membership
    

def encodeGuid( guid : str, headers ):
    return headers["guids"].index(guid)

def decodeGuid( row_coord : int, headers ):
    return headers["guids"][row_coord]

def encodeAllele( allele : str, headers ):
    return headers["alleles"].index(allele)

def decodeAllele( col_coord : int, headers ):
    return headers["alleles"][col_coord]

# data = ["./data/Cparv_matrix.npy", "./data/Cparv_headers.json"]
# ard = Ardal(data)
# ard.stats()

# %%
import numpy as np
import pandas as pd
import json

def create_test_dataset():
    """
    Creates a simulated test dataset for testing the Ardal.unique functionality.

    Returns:
        tuple: A tuple containing the matrix (NumPy array) and headers (dictionary).

    "SNP1" is unique to "GUID1" and "GUID2".
    "SNP2" is unique to "GUID3", "GUID4", and "GUID5".
    "SNP3" is unique to "GUID6" and "GUID7".
    "SNP4" is unique to "GUID8", "GUID9", and "GUID10".
    "SNP5" is present in all GUIDs.
    "SNP6" is present in GUID1, GUID2, GUID3, GUID4, GUID5, GUID6, GUID7.
    "SNP7" is present in GUID1, GUID2, GUID3, GUID4, GUID5, GUID6, GUID7, GUID8, GUID9, GUID10.
    "SNP8" is present in GUID1, GUID2, GUID3, GUID4, GUID5.
    "SNP9" is present in GUID6, GUID7, GUID8, GUID9, GUID10.
    "SNP10" is present in GUID1, GUID2, GUID3, GUID4, GUID5, GUID6, GUID7, GUID8, GUID9.
    """

    # Define GUIDs and SNPs
    guids = [f"GUID{i}" for i in range(1, 11)]  # GUID1 to GUID10
    alleles = [f"SNP{i}" for i in range(1, 11)]  # SNP1 to SNP10

    # Create an empty matrix (all zeros)
    matrix = np.zeros((len(guids), len(alleles)), dtype=np.uint8)

    # Set unique SNPs
    matrix[0, 0] = 1  # SNP1 in GUID1
    matrix[1, 0] = 1  # SNP1 in GUID2
    matrix[2, 1] = 1  # SNP2 in GUID3
    matrix[3, 1] = 1  # SNP2 in GUID4
    matrix[4, 1] = 1  # SNP2 in GUID5
    matrix[5, 2] = 1  # SNP3 in GUID6
    matrix[6, 2] = 1  # SNP3 in GUID7
    matrix[7, 3] = 1  # SNP4 in GUID8
    matrix[8, 3] = 1  # SNP4 in GUID9
    matrix[9, 3] = 1  # SNP4 in GUID10

    # Set SNP5 to be present in all GUIDs
    matrix[:, 4] = 1  # SNP5 in all GUIDs

    # Set SNP6 to be present in GUID1, GUID2, GUID3, GUID4, GUID5, GUID6, GUID7
    matrix[0:7, 5] = 1

    # Set SNP7 to be present in all GUIDs
    matrix[:, 6] = 1

    # Set SNP8 to be present in GUID1, GUID2, GUID3, GUID4, GUID5
    matrix[0:5, 7] = 1

    # Set SNP9 to be present in GUID6, GUID7, GUID8, GUID9, GUID10
    matrix[5:10, 8] = 1

    # Set SNP10 to be present in GUID1, GUID2, GUID3, GUID4, GUID5, GUID6, GUID7, GUID8, GUID9
    matrix[0:9, 9] = 1

    # Create headers
    headers = {
        "guids": guids,
        "alleles": alleles
    }

    return matrix, headers

# %%
import json

with open("/home/arthur/BioInf/Ardal_MAIN/cw_ardal_comparison_WD/sim_headers.json", 'r') as fin:
    jdata = json.load(fin)
    
guids = jdata['guids']
old_alleles = jdata['alleles']

new_alleles = [f"{i[0]}.{i[1:-1]}.{i[-1]}" for i in old_alleles]

new_headers = {"guids" : guids, "alleles" : new_alleles}

with open("/home/arthur/BioInf/Ardal_MAIN/cw_ardal_comparison_WD/sim_headers_new.json", 'w') as fout:
    json.dump(new_headers, fout, indent=4)

# %%
from ardal import Ardal
data = ["/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-5000.npz", "/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-5000_headers.json"]
ard = Ardal(data, roaring="auto", allele_id_format="{ref}.{start}.{alt}", quiet_init=False, verbosity="debug")
ard.distance.pairwise(as_dataframe=True, use_simd=True, threads=16)
ard.distance.knn("England/BRBR-32718B31/2023", 3, backend="bit", use_simd=True, threads=10)
# Out:
# [2025-10-20 13:46:18,462] INFO: Parsing matrix data from two file paths: ['/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-5000.npz', '/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-5000_headers.json']
# [2025-10-20 13:46:18,463] INFO: Detected matrix format: .npz
# [2025-10-20 13:46:18,574] DEBUG: Roaring setter : roaring=auto; density_threshold=0.1; build_roaring=True
# [2025-10-20 13:46:18,574] INFO: Initialising ardal::HybridMatrix backend with:
#                                     matrix = (5000, 9146) <class 'numpy.ndarray'>
#                                     is_bitpacked = False <class 'bool'>
#                                     n_cols_bits = 9146 <class 'int'>
#                                     build_roaring = True <class 'bool'>
#                                     density_threshold = 0.1 <class 'float'>
# [2025-10-20 13:46:18,618] INFO: [BACKEND] Initialising RoaringMatrix backend
# ...

# %% [markdown]
# # Datasets

# %%
import numpy as np
import pandas as pd
import scipy as sp
from ardal import Ardal
import time

# %% [markdown]
# ### IN MEMORY

# %%
guids = [f"GUID{i}" for i in range(1, 11)]  # GUID1 to GUID10
alleles = [f"chr1.{i}.A.T" for i in range(1, 11)]  # SNP1 to SNP10 named as CHR1.{i}.A.T
matrix = np.zeros((len(guids), len(alleles)), dtype=np.uint8)

matrix[0, 0] = 1  ## SNP1 in GUID1
matrix[1, 0] = 1  ## SNP1 in GUID2
matrix[2, 1] = 1  ## SNP2 in GUID3
matrix[3, 1] = 1  ## SNP2 in GUID4
matrix[4, 1] = 1  ## SNP2 in GUID5
matrix[5, 2] = 1  ## SNP3 in GUID6
matrix[6, 2] = 1  ## SNP3 in GUID7
matrix[7, 3] = 1  ## SNP4 in GUID8
matrix[8, 3] = 1  ## SNP4 in GUID9
matrix[9, 3] = 1  ## SNP4 in GUID10

matrix[:, 4] = 1

matrix[0:7, 5] = 1

matrix[:, 6] = 1

matrix[0:5, 7] = 1

matrix[5:10, 8] = 1

matrix[0:9, 9] = 1

headers = {
    "guids": guids,
    "alleles": alleles
}

data = [np.ascontiguousarray(matrix), headers]
ard = Ardal(data, roaring="true", allele_id_format="{chr}.{start}.{ref}.{alt}", quiet_init=False, verbosity="debug")
mem_D = ard.distance.pairwise()
mem_D

# %% [markdown]
# ### SIM

# %%
# %%time
data = ["/home/arthur/BioInf/Ardal_MAIN/Ardal/tests/data/sim_matrix.npz", "/home/arthur/BioInf/Ardal_MAIN/Ardal/tests/data/sim_headers.json"]
ard = Ardal(data, roaring="true", allele_id_format="{chr}.{start}.{ref}.{alt}", quiet_init=False, verbosity="debug")

# %%
def test_ArdalStats_api(stats: "ArdalStats"):
    print("Testing allele_frequency...")
    try:
        freq = stats.allele_frequency()
        print("allele_frequency: OK, result length:", len(freq))
    except Exception as e:
        print("allele_frequency: FAILED:", e)

    print("Testing alleleEntropy...")
    try:
        entropy = stats.alleleEntropy()
        print("alleleEntropy: OK, result length:", len(entropy))
    except Exception as e:
        print("alleleEntropy: FAILED:", e)

    print("Testing allele_cooc...")
    try:
        cooc = stats.allele_cooc()
        print("allele_cooc: OK, result length:", len(cooc))
    except Exception as e:
        print("allele_cooc: FAILED:", e)

    print("Testing allele_inform (kullbackleibler)...")
    try:
        # Provide a minimal valid guids list
        guids = stats._headerUtils.headers["guids"][:2]
        inform = stats.allele_inform(guids, metric="kullbackleibler")
        print("allele_inform (kullbackleibler): OK, result length:", len(inform))
    except Exception as e:
        print("allele_inform (kullbackleibler): FAILED:", e)

    print("Testing allele_inform (jensenshannon)...")
    try:
        guids = stats._headerUtils.headers["guids"][:2]
        inform = stats.allele_inform(guids, metric="jensenshannon")
        print("allele_inform (jensenshannon): OK, result length:", len(inform))
    except Exception as e:
        print("allele_inform (jensenshannon): FAILED:", e)

    print("Testing allele_inform (informationgain)...")
    try:
        guids = stats._headerUtils.headers["guids"][:2]
        inform = stats.allele_inform(guids, metric="informationgain")
        print("allele_inform (informationgain): OK, result length:", len(inform))
    except Exception as e:
        print("allele_inform (informationgain): FAILED:", e)

    print("Testing test_associations (should raise NotImplementedError)...")
    try:
        stats.test_associations(stats._headerUtils.headers["guids"][:2])
        print("test_associations: FAILED (should have raised NotImplementedError)")
    except NotImplementedError:
        print("test_associations: OK (NotImplementedError raised)")
    except Exception as e:
        print("test_associations: FAILED (unexpected exception):", e)
        
test_ArdalStats_api(ard.stats)

# %%
guids = ard.stats._headerUtils.headers["guids"][:20]
ard.distance.pairwise(guids=guids, as_dataframe=True, use_simd=True)

# %% [markdown]
# ### COG

# %%
# %%time
# data = ["/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-5000.npz", "/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-5000_headers.json"]
data = ["/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-100000.npz", "/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps.1-100000_headers.json"]
# data = ["/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps/cog2M.bin", "/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps/cog2M.json"]

ard = Ardal(data, roaring="auto", allele_id_format="{ref}.{start}.{alt}", quiet_init=False, verbosity="debug")
# ard = ard.get.subset(guids=ard.get.headers()['guids'][:20000], threads=1)

# %%
# %%time
ard.distance.knn("England/BRBR-313EBAAA/2021", 300, backend="bit", use_simd=True, threads=10)
# ard.get.headers()

# %%
# %%time
ard.distance.neighbourhood("England/BRBR-313EBAAA/2021", 6, backend='auto', use_simd=True)

# %%
# %%time
# guids = ard.get.headers()["guids"][:50000]
# ard.distance.pairwise(guids=guids, threads=16, backend="bit")
ard.distance.pairwise(threads=16, backend="bit")

# %%
# %%time
data = ["/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps/cog_all.bin", "/home/arthur/BioInf/Ardal_MAIN/Ardal_WD/cog_data/cog_snps/cog_all.json"]
# data = ["./cog100000.bin", "./cog100000.json"]
ard = Ardal(data, roaring="auto", allele_id_format="{ref}.{start}.{alt}", quiet_init=False, verbosity="debug")

# %% [markdown]
# ### CRYPTO

# %%
# %%time
meta = pd.read_csv("/home/arthur/BioInf/Crypto_popgen/data/crypto_meta.csv")
# data = ["/home/arthur/BioInf/Crypto_popgen/all_Cparv_matrix.npy", "/home/arthur/BioInf/Crypto_popgen/all_Cparv_headers.json"]
data = ["/home/arthur/BioInf/Crypto_popgen/cparv_highcov_matrix.npy", "/home/arthur/BioInf/Crypto_popgen/cparv_highcov_headers.json"]
ard = Ardal(data, roaring="auto", density_threshold=1, allele_id_format="{chr}.{start}.{alt}", quiet_init=False, verbosity="debug")

# %% [markdown]
# ### PLASMODIUM

# %%
# %%time
data = ["/home/amorris/BioInf/SSD/BioInf/Plasmodium_vcfs/Pf_matrix.npy", "/home/amorris/BioInf/SSD/BioInf/Plasmodium_vcfs/Pf_headers.json"]
ard = Ardal(data)
# df = pd.read_csv("/home/amorris/BioInf/ProtoDB/WD/Pf_SPT_hamming.csv",  index_col=0)

# %% [markdown]
# ### BURKHOLDERIA

# %%
# %%time
data = ["/home/arthur/BioInf/burkholderia_WD/data/allele_matrices/BG_core_matrix.npy", "/home/arthur/BioInf/burkholderia_WD/data/allele_matrices/BG_core_headers.json"]
ard = Ardal(data, allele_id_format="{chr}.{start}.{alt}", verbosity="debug")
meta = pd.read_csv("/home/arthur/BioInf/burkholderia_WD/data/Mullins_Onion_Jones.csv")

# %%
# %%time
data = ["/home/arthur/BioInf/burkholderia_WD/data/fig3/fig3_PAN_matrix.npy", "/home/arthur/BioInf/burkholderia_WD/data/fig3/fig3_PAN_headers.json"]
ard = Ardal(data, allele_id_format="{chr}.{start}.{alt}", verbosity="debug")
meta = pd.read_csv("/home/arthur/BioInf/burkholderia_WD/data/Mullins_Onion_Jones.csv")

# %% [markdown]
# # COMPUTE

# %%
# bed_content = "chr2\t300\t301\tchr1.100.A.T\n"
# bed_file = open("./test.bed", 'w')
# bed_file.write(bed_content)
# bed_file.close()

bed_content = "chr1\t10\t20\nchr1\t50\t60\nchr1\t80\t90\n"
bed_file = open("./test.bed", 'w')
bed_file.write(bed_content)
bed_file.close()

intervals = [("chr2", 250, 350)]
alleles = ard.allele.interval(intervals_bed="./test.bed")
alleles
# assert "chr1.100.A.T" in alleles

# %%
ard._headerUtils.compute_allele_positions(allele_id_format="{alt}.{start}.{ref}", recompute_positions=True)

# %%
ard.allele.get_positions()

# %%
ard.allele.interval(intervals=[[100, 100000]])

# %%
ard.get.row_masses()

# %%
# %%time
guids = ard.get.headers()['guids'][:50000]
# alleles = ard.get.headers()['alleles'][:10000]
submat = ard.get.subset(guids=guids, threads=1, child_quiet_init=False, child_verbosity="debug")

# print(submat.get.headers()['guids'] == guids)
# print(submat.get.headers()['alleles'] == alleles)

# %%
# %%time
d=ard.distance.neighbourhood(guid="England/BRBR-313EBAE6/2021", n=5, threads=16, backend='roaring')
d

# %%
import time
timings = []
ard.set_verbosity("silent")
for i in range(20):
    s=time.time()
    # d=ard.distance.pairwise(threads=16, return_square=False, as_dataframe=False, backend='roaring', metric='inner_product')
    d=ard.distance.neighbourhood(guid="England/BRBR-313EBAE6/2021", n=100, threads=16, backend='roaring')
    e=time.time()
    timings.append(e-s)
    
mean = np.mean(timings)
var = np.var(timings)
print(mean, var)

# %% [markdown]
# VV BENCHMARKING
#     HAMMING
#     dataset: cog100k
#     static 16t
#     roaring: 3.28
#     bit : crash
#
#     dynamic, 1 16t
#     roaring: 2.37
#     bit : crash
#
#     JACCARD
#     dataset: cog10k
#     static 16t
#     roaring: 0.90-1.13s
#     bit : NA
#
#     dynamic, 1 16t
#     roaring: 0.60-0.63
#     bit : NA
#
#     INNER-PRODUCT
#     dataset: cog10k
#     static 16t
#     roaring: 0.88-1.33
#     bit : NA
#
#     dynamic, 1 16t
#     roaring: 0.56-0.64
#     bit : 2.87-3.05
#
#     NEIGHBOURHOOD:
#     1000it
#     dataset: cog100k
#     static 16t
#     roaring: 0.018313010931015016 5.419876136315337e-07
#     bit : 0.027857343673706056 3.213540645775538e-06
#
#     dynamic, 1 16t
#     roaring: 0.0202056303024292 1.2680130163780632e-06
#     bit : 0.02916682243347168 2.3124020194472905e-06
#
# FLAT BENCHMARKING
#     NEIGHBOURHOOD:
#     1000it
#     16t
#     dataset: cog100k
#
#     schedule(dynamic, 100)
#         roaring manualcard: 0.017503294706344603 3.036477710156192e-07
#         roaring incard: 0.015829519748687744 6.278362576993004e-07
#     schedule(guided, 2048)
#         roaring incard: 0.016189860582351685 3.4753405794793934e-07
#
#     NEIGHBOURHOOD:
#     20it
#     16t
#     dataset: cog2M
#
#     schedule(guided, 2048)
#         roaring incard: 3.1938361644744875 0.009008238963904205
#         roaring incard inline: 3.161026918888092 0.0035617222113232573

# %%
import time
timings = []

for i in range(1000):
    s=time.time()
    # d=ard.distance.pairwise(threads=16, return_square=False, as_dataframe=False, backend='roaring', metric='inner_product')
    d=ard.distance.neighbourhood(guid="England/BRBR-313EBAE6/2021", n=100, threads=16, backend='bit')
    e=time.time()
    timings.append(e-s)
    
mean = np.mean(timings)
var = np.var(timings)
print(mean, var)

# %%
low_cov_samples = list(meta[meta["5x_boc"]<70]["name"])
high_cov_ard = ard.get.subset([i for i in ard.get.headers()["guids"] if i not in low_cov_samples])
# high_cov_ard.io.write("/home/arthur/BioInf/Crypto_popgen/", "cparv_highcov")

# %%
meta = pd.read_csv("/home/arthur/BioInf/Crypto_popgen/data/crypto_meta.csv")
gp60_family = {
    n: (id if pd.notna(id) else "None")
    for n, id in zip(meta["name"], meta["continent"])
}

# gp60_D = ard.compare.pairwise(intervals=[["CP044417", 263936, 264916]], allele_id_format="{chr}.{start}.{alt}")
# nwk = dist2newick(gp60_D)

chr_D = ard.compare.pairwise(intervals=[["CP044420"]], allele_id_format="{chr}.{start}.{alt}")
nwk = dist2newick(chr_D)
plot_colored_tree(nwk, gp60_family)
# plt.close()

# %%
subset_guids = ard.get.headers()['guids'][25:500]
subset_alleles = ard.get.headers()['alleles'][13:10000]
ard_subset = ard.get.subset(guid_list=subset_guids, allele_list=subset_alleles)

# %%
# %%time
s = ard.compare.pairwise(guid_ids=subset_guids, allele_ids=subset_alleles, threads=20)
s

# %%
# %%time
s = ard_subset.compare.pairwise(force_bit_backend=False)

# %%
# %%time
r = ard.compare.pairwise(force_bit_backend=False, threads=20)
r = r.loc[subset_guids, subset_guids]

# %%
ard.io.write("/home/arthur/BioInf/Crypto_popgen/", "test", npz=True)

# %%
# %%time
bm = ard.compare.pairwise(threads=20, metric="hamming", use_simd=True)
bm

# %%
# %%time
rm = ard.distance.pairwise(threads=1, use_simd=True)

# %%
# %%time
ard.distance.pairwise(threads=1, use_simd=True, force_bit_backend=True)

# %%
n=42663
o = 10/(((n**2)-n)/2)

n=7485492
t=o*(((n**2)-n)/2)
t/60/60

# %%
ard.get.headers()["alleles"]

# %%
ard.allele.interval(intervals=[["CP044415", "1000", "200000"], ["CP044415", 26000, "300000"]])

# %%
guids = ard.get.headers()['guids'][:2]
s=time.time()
uc = ard.allele.unique_core(guids, backend='bit')
e=time.time()
print(uc)

# s=time.time()
# uc = ard.uniqueSNPs(ard.getHeaders()["guids"])
# e=time.time()
# print(uc)
# print(e-s)

# %%
import numpy as np

times_8b = [1.0770680904388428,
 0.9564015865325928,
 0.9266269207000732,
 0.9804456233978271,
 1.0449635982513428,
 0.932440996170044,
 1.083590030670166,
 1.0518584251403809,
 1.0249264240264893,
 0.9217827320098877,
 0.915233850479126,
 0.9014880657196045,
 0.8615577220916748,
 0.8025546073913574,
 0.9000663757324219,
 0.8638675212860107,
 0.8360249996185303,
 0.8303425312042236,
 0.8492426872253418,
 0.8452434539794922,
 0.7771217823028564,
 0.8467543125152588,
 0.8693892955780029,
 0.8583815097808838,
 0.9150390625,
 0.940866231918335,
 0.9561994075775146,
 0.9101982116699219,
 0.9020373821258545,
 0.9040660858154297,
 0.9465878009796143,
 0.916527509689331,
 0.8308908939361572,
 0.9515726566314697,
 0.9152812957763672,
 0.8268358707427979,
 0.8728427886962891,
 0.9295732975006104,
 0.8954501152038574,
 0.9204943180084229,
 0.876598596572876,
 0.8885018825531006,
 0.8454623222351074,
 0.8781425952911377,
 0.8639717102050781,
 0.8419559001922607,
 0.8393452167510986,
 0.9115502834320068,
 0.9615654945373535,
 0.8346691131591797,
 0.9303493499755859,
 0.9762277603149414,
 0.8026485443115234,
 0.9505205154418945,
 0.9750576019287109,
 0.8794903755187988,
 0.877816915512085,
 0.8553218841552734,
 0.8543128967285156,
 0.7846837043762207,
 0.9029428958892822,
 0.95377516746521,
 0.8806362152099609,
 0.8176040649414062,
 0.8354783058166504,
 0.9475157260894775,
 0.8072993755340576,
 0.8884134292602539,
 0.9382333755493164,
 0.9520506858825684,
 0.9621388912200928,
 0.882835865020752,
 0.797072172164917,
 0.905665397644043,
 0.8693788051605225,
 0.9127428531646729,
 0.8723819255828857,
 0.9867475032806396,
 0.9202797412872314,
 0.9854233264923096,
 0.9892833232879639,
 0.7457780838012695,
 0.7712104320526123,
 0.924187421798706,
 0.8112540245056152,
 0.9056565761566162,
 0.9087786674499512,
 0.8319082260131836,
 0.8854019641876221,
 0.826343297958374,
 0.8928563594818115,
 0.8384084701538086,
 0.902036190032959,
 1.011549711227417,
 0.7836933135986328,
 0.8369872570037842,
 0.8236582279205322,
 0.8884732723236084,
 0.886883020401001,
 0.9454362392425537]

np.mean(times)
np.mean(times_8b)

# %%
times = []
for i in range(100):
    s=time.time()
    cog_ham = ard.pairwise(metric="hamming", threads=10, use_simd=True)
    e=time.time()
    print(e-s)
    times.append(e-s)

# clus = cluster(cog_ham, 5)
# print(clus)
# makePCA(cog_ham, clus)

# %%
ard.alleleEntropy()

# for i, (a, ent) in enumerate(all_ent.items()):
#     if i==10:
#         break
#     print(a, ent)
#     print(ard.allele([a]))

# %%
ingroup_str = """SRR21763624_Calf10
SRR21763626_Calf8
SRR21763629_Lamb5
SRR21763631_Lamb3
SRR21763633_Calf13
SRR21763636_Lamb1
SRR26320644_UKP125
SRR26320645_UKP124
SRR26320655_UKP104
SRR26320657_UKP102
SRR26320663_Swe2
SRR26320681_Hun2
SRR26320696_GER21
SRR26320709_FIN2
SRR26320733_FIN4
SRR26320737_FIN1
SRR10363424_41567
"""
ingroup = [x.strip() for x in ingroup_str.split("\n") if x.strip()]
snps = ard.snpInform(ingroup, metric="kullbackleibler")
snps

# %%
ard.alleleCooc(list(snps.keys())[:1000], threshold=0.95, threads=10)

# %%
matrix, headers = create_test_dataset()
ard = Ardal([matrix, headers])
cpp_ard = _ardal.AlleleMatrix(matrix)

alleles = ["SNP5", "SNP10"]
n = len(alleles)
allele_coords = [encodeAllele(allele) for allele in alleles]
input_coords = np.array([[encodeGuid(guid), allele] for guid in ard.getHeaders()["guids"] for allele in allele_coords])
access_result = zip(input_coords, cpp_ard.access(input_coords))
# print(list(result))
decoded_results = [decodeGuid(guid_c) for (guid_c, allele_c), r in access_result if r==1]

results = [guid for guid in set(decoded_results) if decoded_results.count(guid) == n]

print(results)

# %%
import time
d = 90000
g = "ERR1100643"
# ard.flushCache()
s = time.time()
ard_neigh = ard.neighbourhood(g, d, simd=True)
e = time.time()

ard_neigh
# e-s

# %%
cat = dict(zip(list(meta["SRA"]), list(meta["Clade"])))
clus = cluster(ardD_hamming, 10)
makePCA(ardD_hamming, clus, D3=True)

# %%
guid_ids = [guid for guid, c in clus.items() if c in [5]]
print(guid_ids)
d1 = ard.unique(guid_ids)

d = {'GCA_902830895.1_ASM90283089v1_genomic.4394500.T',
 'GCA_902830905.1_ASM90283090v1_genomic.1733623.C',
 'GCA_902830905.1_ASM90283090v1_genomic.1759564.C',
 'GCA_902830905.1_ASM90283090v1_genomic.3025340.A',
 'GCA_902830905.1_ASM90283090v1_genomic.4319502.C',
 'GCA_902831285.1_ASM90283128v1_genomic.4462753.T',
 'GCA_902831285.1_ASM90283128v1_genomic.446892.C'}

d1

# %%
d = 2000000
g = "SPT12274"
neigh = df.loc[g][df.loc[g] < d].to_dict()
ard_neigh = ard.neighbourhood(g, d, simd=True)

results_box = {"ardal" : ard_neigh, "hamming" : neigh}

results_df = pd.DataFrame(results_box).sort_values(by="ardal", ascending=True)
results_df = results_df.drop(g)

matching_guids = []
mismatching_guids = []

for guid in results_df.index:
    if results_df.loc[guid, "ardal"] == results_df.loc[guid, "hamming"]:
        matching_guids.append(guid)
    else:
        mismatching_guids.append(guid)

# print(bools)
print(f"MATCH : {len(matching_guids)}")
print(f"MISMATCH : {len(mismatching_guids)} {mismatching_guids}")

# %%
results_df.loc["SPT43391"]
len(headers["alleles"])%32

# %%
# num_samples = 100
# num_alleles = 50
# allele_matrix = np.random.randint(0, 2, (num_samples, num_alleles))

K = 4

X=ard.getMatrix()
nmf = NMF(n_components=K, init='random', random_state=12)
W = nmf.fit_transform(X)
H = nmf.components_

W = W/np.sum(W, axis=1)[:, np.newaxis]

cluster_assignments = np.argmax(H, axis=0)

fig, ax = plt.subplots(figsize=(10, 6))

bottom = np.zeros(ard.stats()["n_guids"])
for k in range(K):
    ax.bar(range(ard.stats()["n_guids"]), W[:, k], bottom=bottom, label=f'Ancestry {k+1}')
    bottom += W[:, k]

ax.set_xlabel('Sample')
ax.set_ylabel('Admixture Proportion')
ax.set_title(f'Admixture Proportions (K={K})')
ax.legend()

guids = ard.getHeaders()["guids"]
plt.xticks(range(len(guids)), guids, rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import NMF, PCA

# 1. Dimensionality Reduction (if necessary)
if W.shape[1] > 3:
    pca = PCA(n_components=3)  # Reduce to 3D for plotting
    W_reduced = pca.fit_transform(W)
elif W.shape[1] == 3:  # Already 3D
    W_reduced = W
else: # If W has fewer than 3 components, we'll pad it with zeros.
    W_reduced = np.pad(W, ((0,0), (0, 3 - W.shape[1])), mode='constant')



# 2. 3D Scatter Plot
# col_cat = np.argmax(W, axis=1)  # Get dominant ancestry for coloring
col_cat = np.max(W, axis=1)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d') # Create a 3D axes


scatter = ax.scatter(W_reduced[:, 0], W_reduced[:, 1], W_reduced[:, 2], c=col_cat, cmap='viridis')


ax.set_title("NMF Admixture 3D Scatter Plot")


# Set labels based on dimensionality reduction or original W matrix:
if W.shape[1] > 3:  # If PCA was used
    ax.set_xlabel("Principal Component 1")
    ax.set_ylabel("Principal Component 2")
    ax.set_zlabel("Principal Component 3")
elif W.shape[1] == 3:
    ax.set_xlabel("Ancestry Component 1")  # Adjust if you have specific names
    ax.set_ylabel("Ancestry Component 2")
    ax.set_zlabel("Ancestry Component 3")
else:
    ax.set_xlabel("Ancestry Component 1")
    ax.set_ylabel("Ancestry Component 2")
    ax.set_zlabel("Padding") # Indicate that the third dimension is padding


fig.colorbar(scatter, label="Dominant Ancestry")
plt.show()

# %%
colors = ['red', 'green', 'blue', 'purple']

# Number of samples and ancestries
n_samples, n_ancestries = W.shape

# Create the admixture bar plot
fig, ax = plt.subplots(figsize=(10, 6))  # Adjust figure size if needed

bottom = np.zeros(n_samples)  # Starting point for each bar segment

for k in range(n_ancestries):
    ax.bar(range(n_samples), W[:, k], bottom=bottom, color=colors[k % len(colors)], label=f"Ancestry {k+1}")
    bottom += W[:, k]  # Update the bottom for the next ancestry component


# Customize the plot
ax.set_xticks(range(n_samples))
ax.set_xticklabels(range(1, n_samples + 1))  # Or use sample names if available
ax.set_xlabel("Sample")
ax.set_ylabel("Admixture Proportion")
ax.set_title("Admixture Bar Plot")

ax.legend(title="Ancestries")
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()


# Number of samples and ancestries
n_samples, n_ancestries = W.shape

# Create the admixture bar plot
fig, ax = plt.subplots(figsize=(10, 6))  # Adjust figure size if needed

bottom = np.zeros(n_samples)  # Starting point for each bar segment

for k in range(n_ancestries):
    ax.bar(range(n_samples), W[:, k], bottom=bottom, color=colors[k % len(colors)], label=f"Ancestry {k+1}")
    bottom += W[:, k]  # Update the bottom for the next ancestry component


# Customize the plot
ax.set_xticks(range(n_samples))
ax.set_xticklabels(range(1, n_samples + 1))  # Or use sample names if available
ax.set_xlabel("Sample")
ax.set_ylabel("Admixture Proportion")
ax.set_title("Admixture Bar Plot")

ax.legend(title="Ancestries")
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
print(np.max(W, axis=1))
W

# %%
guids = list(b20_n.keys())
print(guids)
s = time.time()
core = ard.core(guids, 0.9)
e = time.time()

accessory = ard.accessory(guids, 0.9)

print(e-s)
print(len(core), len(accessory), len(core)+len(accessory))

d = defaultdict(list)
for c in core:
    d[c.split(".")[0]].append(c)

# %%
def decodeAlleleID( allele_id : str,
                    allele_id_format : str = "{chr}.{start}.{ref}.{alt}" ) -> tuple :
    """ Decodes an allele ID string into its constituent parts based on a format string.

    Args:
        allele_id (str): The allele ID string to decode (e.g., `chr1.100.200.A.T``).
        allele_id_format (str): The format string defining the structure of the allele ID,
                                 using placeholders like {ref}, {chr}, {start}, {end}, {alt}.
                                 (e.g., "{chr}.{start}.{end}.{ref}.{alt}").

    Returns:
        tuple: A tuple containing the decoded positional tuple (chr, start, end, ref, alt).

    Raises:
        ValueError: If the allele_id does not match the allele_id_format.
    """
    import re
    
    accepted_placeholder_patterns = ["chr", "start", "end", "ref", "alt"]
    
    if not allele_id_format:
        raise ValueError("allele_id_format cannot be empty.")
    if not allele_id:
        raise ValueError("allele_id cannot be empty.")
    
    ## check placeholders are valid
    pattern_placeholders = re.findall(r'\{([^}]+)\}', allele_id_format)
    print(pattern_placeholders)
    for p in pattern_placeholders:
        if p not in accepted_placeholder_patterns:
            raise ValueError(f"{p} not a valid placeholder for allele_id_format pattern. Accepted placeholders : {accepted_placeholder_patterns}")
        
    pattern = re.escape(allele_id_format)
    
    if not pattern:
        raise ValueError("allele_id_format could not be parsed. Please check your format string and ensure it contains valid placeholders.")

    ## define placeholders and their regex pattern
    placeholders = {
        'ref': r'(?P<ref>.+)',
        'chr': r'(?P<chr>.+)',
        'start': r'(?P<start>\d+)',
        'end': r'(?P<end>\d+)',
        'alt': r'(?P<alt>.+)'
    }

    found_placeholders = 0
    ## eeplace escaped placeholders with their regex capture groups
    for key, regex_pattern in placeholders.items():
        escaped_placeholder = re.escape(f"{{{key}}}")
        if escaped_placeholder in pattern:
            pattern = pattern.replace(escaped_placeholder, regex_pattern)
            found_placeholders += 1

    if found_placeholders == 0:
        raise ValueError("allele_id_format does not contain any valid placeholders (e.g., {chr}, {start}).")

    ## anchor the pattern to match the entire string
    pattern = f"^{pattern}$"

    ## compile the regex and match against the allele ID
    match = re.compile(pattern).match(allele_id)

    if not match:
        raise ValueError(f"Allele ID '{allele_id}' does not match the format '{allele_id_format}'.")

    parts = match.groupdict()

    start = int(parts['start']) if 'start' in parts else None
    end = int(parts['end']) if 'end' in parts else None

    return (
        parts.get('chr'),
        start,
        end,
        parts.get('ref'),
        parts.get('alt')
    )



def getIntervalAlleles( intervals : list,
                        headers : dict,
                        allele_id_format : str,
                        coords_bed : str=None ) -> list:
    
    ## get allele positions
    allele_positions = getAllelePositions( intervals,
                                           headers,
                                           allele_id_format,
                                           coords_bed )

    ## find alleles which fall within the given intervals
    interval_alleles = []
    for interval in intervals:
        if len(interval) == 3:
            chr, start, end = interval
            chr = str(chr)
            start = int(start)
            end = int(end)
        elif len(interval) == 2:
            start, end = interval
            chr = None
            start = int(start)
            end = int(end)
        else:
            raise ValueError(f"Intervals must be either [chr, start, end] or [start, end] : {interval}")
    
        if chr:
            pos_dict = allele_positions[chr]
        else:
            pos_dict = allele_positions
            
        sorted_positions = sorted(pos_dict.keys())
        
        for pos in sorted_positions:
            if start <= pos <= end:
                interval_alleles.extend(pos_dict[pos])
        
    return interval_alleles
            

def getAllelePositions( intervals : list,
                        headers : dict,
                        allele_id_format : str,
                        coords_bed : str=None ) -> dict:

    if coords_bed:
        coords = readCoordsBED(coords_bed)
    else:
        coords = None

    ## get the position of each allele
    allele_positions = defaultdict(lambda: defaultdict(list))
    for allele in headers["alleles"]:
        if coords:
            chr, start, end = coords[allele]
            allele_positions[chr][start].append(allele)
        else:
            chr, start, end, ref, alt = decodeAlleleID(allele, allele_id_format)
            allele_positions[chr][start].append(allele)
    
    return allele_positions
        
        
def readCoordsBED( coords_bed : str ) -> dict:
    """ Read the coords BED file containing position : allele_id mappings.
    Must be structures as:
    chr start end allele_id
    """
    with open(coords_bed, 'r') as fin:
        lines = fin.readlines()
    
    coords = defaultdict(list)
    for line in lines:
        chr, start, end, allele_id = line.strip().split()
        coords[allele_id] = [chr, start, end]
    
    return coords



# allele_ids = ["chr1.100.101.A.T", "chr2.200.201.G.C", "chr3.300.303.ACT.TCA"]
# id_format = "{chr}.{start}.{end}.{ref}.{alt}"
allele_ids = ["A.100.T", "G.222.C", "TGG.245.A"]
id_format = "{alt}.{start}.{pee}"

for aid in allele_ids:
    print(decodeAlleleID(aid, id_format))

# %%
from ardal import Ardal
import numpy as np

def valid_headers(n_rows, n_cols):
    return {
        "guids": [f"s{i}" for i in range(n_rows)],
        "alleles": [f"a{j}" for j in range(n_cols)]
    }

matrix = np.ones((3, 5), dtype=np.uint8)
headers = valid_headers(2, 5)  # wrong number of guids
print(type(matrix), type(headers))
Ardal([matrix, headers])

# %%
from ardal import Ardal

ard_obj = Ardal(["/home/arthur/BioInf/Ardal_MAIN/Ardal/tests/data/sim_headers.json", "/home/arthur/BioInf/Ardal_MAIN/Ardal/tests/data/sim_matrix.npy"], quiet=True)

# ard_obj.io.write(file_path="/home/arthur/BioInf/Ardal_MAIN/Ardal/tests/data", output_prefix="test", npz=True)
# ard_obj.io.toDataFrame().to_csv("/home/arthur/BioInf/Ardal_MAIN/Ardal/tests/data/sim_matrix.csv")
ard_obj.get.hybridMatrix()

# %%
import numpy as np
from ardal import Ardal

guids = [f"GUID{i}" for i in range(1, 11)]  # GUID1 to GUID10
alleles = [f"SNP{i}" for i in range(1, 11)]  # SNP1 to SNP10

matrix = np.zeros((len(guids), len(alleles)), dtype=np.uint8)

## set SNPs
matrix[0, 0] = 1  ## SNP1 in GUID1
matrix[1, 0] = 1  ## SNP1 in GUID2
matrix[2, 1] = 1  ## SNP2 in GUID3
matrix[3, 1] = 1  ## SNP2 in GUID4
matrix[4, 1] = 1  ## SNP2 in GUID5
matrix[5, 2] = 1  ## SNP3 in GUID6
matrix[6, 2] = 1  ## SNP3 in GUID7
matrix[7, 3] = 1  ## SNP4 in GUID8
matrix[8, 3] = 1  ## SNP4 in GUID9
matrix[9, 3] = 1  ## SNP4 in GUID10

## SNP5 in all GUIDs
matrix[:, 4] = 1

## SNP6 in GUID1-7
matrix[0:7, 5] = 1

## SNP7 in all GUIDs
matrix[:, 6] = 1

## SNP8 in GUID1-5
matrix[0:5, 7] = 1

## SNP9 in GUID6-10
matrix[5:10, 8] = 1

## SNP10 present in GUID1-9
matrix[0:9, 9] = 1

## header json
headers = {
    "guids": guids,
    "alleles": alleles
}

ard_obj = Ardal([matrix, headers])
# ard_obj.io.toDict()
ard_obj.allele.uniqueCore(["GUID1", "GUID2"], force_bit_backend=True)
